# %%
import pandas as pd
import numpy as np
from numpy import nan

# %%
data= pd.read_csv('C:/Users/Abdelrahman Elsayed/Downloads/cleaning-data-python-data-playbook/artwork_sample.csv')

# %%
data.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
data.dtypes
# Out:
# id                      int64
# accession_number       object
# artist                 object
# artistRole             object
# artistId                int64
# title                  object
# dateText               object
# medium                 object
# creditLine             object
# year                  float64
# acquisitionYear         int64
# dimensions             object
# width                   int64
# height                  int64
# depth                 float64
# units                  object
# inscription           float64
# thumbnailCopyright    float64
# thumbnailUrl           object
# url                    object
# dtype: object

# %%
#to change the data type we use astype(datatype)
data.acquisitionYear=data.acquisitionYear.astype(float)

# %%
 data.acquisitionYear
# Out:
# 0    1922.0
# 1    1922.0
# 2    1922.0
# 3    1922.0
# 4    1919.0
# 5    1919.0
# 6    1919.0
# 7    1919.0
# 8    1919.0
# 9    1919.0
# Name: acquisitionYear, dtype: float64

# %%
fulldf=pd.read_csv('C:/Users/Abdelrahman Elsayed/Downloads/cleaning-data-python-data-playbook/artwork_data.csv',low_memory=False)

# %%
fulldf.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
fulldf.dtypes
# Out:
# id                      int64
# accession_number       object
# artist                 object
# artistRole             object
# artistId                int64
# title                  object
# dateText               object
# medium                 object
# creditLine             object
# year                   object
# acquisitionYear       float64
# dimensions             object
# width                  object
# height                 object
# depth                 float64
# units                  object
# inscription            object
# thumbnailCopyright     object
# thumbnailUrl           object
# url                    object
# dtype: object

# %%
#in case of error in the tranforme action we don't use astype instead we use to_numeric
fulldf.height=pd.to_numeric(fulldf.height,errors='coerce')

# %%
fulldf.height.dtypes
# Out:
# dtype('float64')

# %%
data.describe()
# Out:
#                id   artistId         year  acquisitionYear       width  \
# count    10.00000  10.000000     7.000000        10.000000   10.000000
# mean   1039.50000  38.600000  1820.142857      1920.200000  282.100000
# std       3.02765   0.516398    15.496543         1.549193   55.562677
# min    1035.00000  38.000000  1785.000000      1919.000000  240.000000
# 25%    1037.25000  38.000000  1826.000000      1919.000000  242.250000
# 50%    1039.50000  39.000000  1826.000000      1919.000000  244.500000
# 75%    1041.75000  39.000000  1826.000000      1922.000000  316.250000
# max    1044.00000  39.000000  1826.000000      1922.000000  394.000000
#
#            height  depth  inscription  thumbnailCopyright
# count   10.000000    0.0          0.0                 0.0
# mean   351.500000    NaN          NaN                 NaN
# std     66.818577    NaN          NaN                 NaN
# min    213.000000    NaN          NaN                 NaN
# ...

# %%
#to normallizing the data
#we choose the floats or ints in the files
height= data.height

# %%
norm=(height-height.mean())/height.std()

# %%
norm
# Out:
# 0    1.010198
# 1   -2.072777
# 2    1.728561
# 3    0.636051
# 4   -0.246937
# 5   -0.202040
# 6   -0.261903
# 7   -0.172108
# 8   -0.246937
# 9   -0.172108
# Name: height, dtype: float64

# %%
#also we can normalizing the data between the 1 and 0 as min and max as
minmax=(height-height.min())/(height.max()-height.min())

# %%
minmax
# Out:
# 0    0.811024
# 1    0.000000
# 2    1.000000
# 3    0.712598
# 4    0.480315
# 5    0.492126
# 6    0.476378
# 7    0.500000
# 8    0.480315
# 9    0.500000
# Name: height, dtype: float64

# %%
minmax.max()
# Out:
# 1.0

# %%
minmax.min()
# Out:
# 0.0

# %%
#we will transfroming the data in the data file
#aslo we can use groupby function to manipulate a specific column or values 
#and use transform function to manipulate the data

# %%
#filtering data to select a specific columns to work with

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 20 columns):
# id                    10 non-null int64
# accession_number      10 non-null object
# artist                10 non-null object
# artistRole            10 non-null object
# artistId              10 non-null int64
# title                 10 non-null object
# dateText              10 non-null object
# medium                10 non-null object
# creditLine            10 non-null object
# year                  7 non-null float64
# acquisitionYear       10 non-null float64
# dimensions            10 non-null object
# width                 10 non-null int64
# height                10 non-null int64
# depth                 0 non-null float64
# units                 10 non-null object
# inscription           0 non-null float64
# thumbnailCopyright    0 non-null float64
# thumbnailUrl          10 non-null object
# url                   10 non-null object
# ...

# %%
#to take out the white spaces
fulldf.title=fulldf.title.str.strip()

# %%
fulldf
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
fulldf.loc[fulldf.title.str.contains('\s$',regex=True)]
# Out:
# Empty DataFrame
# Columns: [id, accession_number, artist, artistRole, artistId, title, dateText, medium, creditLine, year, acquisitionYear, dimensions, width, height, depth, units, inscription, thumbnailCopyright, thumbnailUrl, url]
# Index: []

# %%
#we use replace function to replace the 'date un known' in the file to Nan
pd.isna(fulldf.loc[:,'dateText'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 69196    False
# 69197    False
# 69198    False
# 69199    False
# 69200    False
# Name: dateText, Length: 69201, dtype: bool

# %%
fulldf.replace({'dateText':{'date not known':nan}},inplace=True)

# %%
fulldf.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...                     NaN
# 1  Two Drawings of Frightened Figures, Probably f...                     NaN
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms                     NaN
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
#using loc function to locate the not a number values and conatins str in them
fulldf.loc[fulldf.year.notnull() & fulldf.year.astype(str).str.contains('[^0-9]'),['year']] = nan

# %%
fulldf
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
fulldf.iloc[67968:67969]
# Out:
#           id accession_number            artist artistRole  artistId  \
# 67968  99332           T12629  Roberts, William     artist      1855
#
#                      title dateText             medium  \
# 67968  Families on a beach  no date  Graphite on paper
#
#                                               creditLine year  \
# 67968  Accepted by HM Government in lieu of inheritan...  NaN
#
#        acquisitionYear             dimensions width  height  depth units  \
# 67968           2008.0  support: 127 x 178 mm   127   178.0    NaN    mm
#
#       inscription               thumbnailCopyright  \
# 67968         NaN  © The estate of William Roberts
#
#                                             thumbnailUrl  \
# 67968  http://www.tate.org.uk/art/images/work/T/T12/T...
#
#                                                      url
# 67968  http://www.tate.org.uk/art/artworks/roberts-fa...

# %%
#filling missing values
fulldf.fillna(value={'depth': fulldf.depth.mean()},inplace=True)

# %%
fulldf
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
fulldf.loc[fulldf.depth>1000]
# Out:
#            id accession_number                 artist artistRole  artistId  \
# 1758    95468          AR00021   Hamilton Finlay, Ian     artist      1093
# 1771    98292          AR00034             Mueck, Ron     artist      2672
# 1772    99124          AR00035             Mueck, Ron     artist      2672
# 1816    98200          AR00079            Koons, Jeff     artist      2368
# 2345    98289          AR00608            Merz, Mario     artist      1623
# ...       ...              ...                    ...        ...       ...
# 69096  106713           T13765  Cruzvillegas, Abraham     artist     13142
# 69098  106715           T13767  Cruzvillegas, Abraham     artist     13142
# 69111  106943           T13780  Cruzvillegas, Abraham     artist     13142
# 69159  123246           T13828       Griffiths, Brian     artist     13287
# 69198  121181           T13867           Hatoum, Mona     artist      2365
#
#                                             title dateText  \
# ...

# %%
#we use dropna function to drop rows that have nan

# %%
#we can use drop_duplicate to drop the duplicate values in a data set
